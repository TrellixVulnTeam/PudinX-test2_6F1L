# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\desktop\pycharmprojects\datascrapping_tiktok\tiktokanalytics\lib\site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\desktop\pycharmprojects\datascrapping_tiktok\tiktokanalytics\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\desktop\pycharmprojects\datascrapping_tiktok\tiktokanalytics\lib\site-packages (from pandas) (1.22.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\desktop\pycharmprojects\datascrapping_tiktok\tiktokanalytics\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\desktop\pycharmprojects\datascrapping_tiktok\tiktokanalytics\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
import pandas as pd

# %%
df = pd.read_json('export.json')

# %%
df.head()
# Out:
#                     id                                               desc  \
# 0  7060891291281853440  Romain Grosjean F1 Accident (Recreate) #f1 #fo...
# 1  7057218917479025664  Michael and Ferrari entering god mode 🐐 cr:@ma...
# 2  7024487957276969984  Now that's impressive #f1 #formula1 #racing #s...
# 3  7076476934401674240  Responder a @alison_ov_30 comenten para última...
# 4  6979913192277298176  One of the scariest things I’ve ever seen.. #f...
#
#    createTime                                              video  \
# 0  1643991865  {'id': '7060891291281853722', 'height': 768, '...
# 1  1643136824  {'id': '7057218917479025925', 'height': 576, '...
# 2  1635516054  {'id': '7024487957276970245', 'height': 1024, ...
# 3  1647620680  {'id': '7076476934401674502', 'height': 960, '...
# 4  1625137688  {'id': '6979913192277298438', 'height': 1024, ...
#
#                                               author  \
# 0  {'id': '6655523690707550213', 'uniqueId': 'anj...
# 1  {'id': '6911982542149682181', 'uniqueId': 'for...
# 2  {'id': '6757296767807308805', 'uniqueId': 'f1h...
# 3  {'id': '6808312073073165317', 'uniqueId': 'mic...
# 4  {'id': '6761781523756270597', 'uniqueId': 'jin...
#
#                                                music  \
# 0  {'id': '7060891344105507610', 'title': 'origin...
# 1  {'id': '7006987872406702854', 'title': 'sonido...
# 2  {'id': '6960037601793362694', 'title': 'idfc',...
# 3  {'id': '7076476975736425222', 'title': 'sonido...
# 4  {'id': '6979912966737070853', 'title': 'origin...
#
#                                           challenges  \
# 0  [{'id': '16520', 'title': 'F1', 'desc': 'Get y...
# 1  [{'id': '153828', 'title': 'fy', 'desc': '', '...
# 2  [{'id': '16520', 'title': 'F1', 'desc': 'Get y...
# 3  [{'id': '20297580', 'title': 'historias', 'des...
# 4  [{'id': '16520', 'title': 'F1', 'desc': 'Get y...
#
#                                                stats             duetInfo  \
# 0  {'diggCount': 4000000, 'shareCount': 47000, 'c...  {'duetFromId': '0'}
# 1  {'diggCount': 3000000, 'shareCount': 38600, 'c...  {'duetFromId': '0'}
# 2  {'diggCount': 2400000, 'shareCount': 26700, 'c...  {'duetFromId': '0'}
# 3  {'diggCount': 2300000, 'shareCount': 4334, 'co...  {'duetFromId': '0'}
# 4  {'diggCount': 2100000, 'shareCount': 15000, 'c...  {'duetFromId': '0'}
#
#    originalItem  ...  privateItem duetEnabled  stitchEnabled  shareEnabled  \
# 0         False  ...        False       False          False          True
# 1         False  ...        False       False          False          True
# 2         False  ...        False        True           True          True
# 3         False  ...        False       False          False          True
# 4         False  ...        False        True           True          True
#
#     isAd  duetDisplay  stitchDisplay  \
# 0  False            0              0
# 1  False            0              0
# 2  False            0              0
# 3  False            0              0
# 4  False            0              0
#
#                                       stickersOnItem  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3   [{'stickerType': 9, 'stickerText': ['Parte 4']}]
# 4  [{'stickerType': 4, 'stickerText': ['one of th...
#
#                                             warnInfo effectStickers
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4  [{'text': 'Participating in this activity coul...            NaN
#
# [5 rows x 30 columns]

# %%
df.to_csv('TikTokAnalytics_data.csv')

# %%
import json

# %%
with open ('export.json', 'r') as f:
    data = json.load(f)

# %%
nested_values = ['video', 'author', 'music', 'stats', 'authorStats', 'challenges', 'duetInfo', 'textExtra', 'stickersOnItem']
skip_values = ['challenges', 'duetInfo', 'textExtra', 'stickersOnItem']

# %%
# Create blank dictionary
flattened_data = {}
# Loop through each video
for idx, value in enumerate(data): 
    flattened_data[idx] = {}
    # Loop through each property in each video 
    for prop_idx, prop_value in value.items():
        # Check if nested
        if prop_idx in nested_values:
            if prop_idx in skip_values:
                pass
            else:
                # Loop through each nested property
                for nested_idx, nested_value in prop_value.items():
                    flattened_data[idx][prop_idx+'_'+nested_idx] = nested_value
        # If it's not nested, add it back to the flattened dictionary
        else: 
            flattened_data[idx][prop_idx] = prop_value

# %%
type(flattened_data)
# Out:
# dict

# %%
df_test = pd.DataFrame.from_dict(flattened_data, orient='index')

# %%
df_test['createTime'] = pd.to_datetime(df['createTime'], unit='s')

# %%
print(df_test)
# Out:
#                      id                                               desc  \
# 0   7060891291281853722  Romain Grosjean F1 Accident (Recreate) #f1 #fo...
# 1   7057218917479025925  Michael and Ferrari entering god mode 🐐 cr:@ma...
# 2   7024487957276970245  Now that's impressive #f1 #formula1 #racing #s...
# 3   7076476934401674502  Responder a @alison_ov_30 comenten para última...
# 4   6979913192277298438  One of the scariest things I’ve ever seen.. #f...
# 5   7062398294957526319  ‘The woman was too stunned to speak’ 😂 #racing...
# 6   6951673377941769478  F1 training is fun... they said... #redbull #r...
# 7   7028146294069693697  lewis is different 🤷‍♂️ #formula1 #f1 #lewisha...
# 8   6860810558384426245  awkward conversations will follow 😬 #f1 #sport...
# 9   7003402608912190726  Incredible relay 😱                            ...
# 10  6891297674083962113  Welcome to the gulag #f1 #formula1 #racing #sp...
# 11  6975160577014369542  it do be stripey tho 😳 #f1 #formula1  #sports ...
# 12  7036734314754739461                     👀👀👀 #fyp #f1 #reactions #gasly
# 13  6966871918121061637  Bottas from the next race🇫🇮                 #b...
# 14  6805554078874127621  Another #amazing #reveal here of 2015 Sauber #...
# 15  6965882414828768518  Reply to @jacksonheaton how the @f1 safety car...
# 16  6992586770923687173                          Garage swag 😎 #F1 style 🔥
# 17  7015013567703403782  @F1 logo written with parallel pen #lettering ...
# 18  7042043642210536710           #f1 #nascar #formula1 #maxverstappen #33
# 19  7064510317522357505  Let's go! Let's go! Drift party!#Koreadrift #d...
://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3   https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 4   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 5   https://p16-sign.tiktokcdn-us.com/obj/tos-usea...
# 6   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 7   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 8   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 9   https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 10  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 11  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 12  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 13  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 14  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 15  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 16  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 17  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 18  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 19  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 20  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 21  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 22  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 23  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 24  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 25  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 26  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 27  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 28  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 29  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
#
#                                     video_originCover  ... authorStats_heart  \
# 0   https://p16-sign-va.tiktokcdn.com/obj/tos-usea...  ...           4000000
# 1   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           3200000
# 2   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          20000000
# 3   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          10500000
# 4   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           2400000
# 5   https://p19-sign.tiktokcdn-us.com/obj/tos-usea...  ...          17600000
# 6   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           9000000
# 7   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...           2500000
# 8   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          62600000
# 9   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           1700000
# 10  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...          20000000
# 11  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          62600000
# 12  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           2200000
# 13  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           1800000
# 14  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           8600000
# 15  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           4800000
# 16  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          24600000
# 17  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          23200000
# 18  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           1600000
# 19  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...           4100000
# 20  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...           2000000
# 21  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           3400000
# 22  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...          62600000
# 23  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          41700000
# 24  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...          62600000
# 25  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           2900000
# 26  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           1100000
# 27  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...          62600000
# 28  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           3000000
# 29  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...           5300000
#
#    privateItem duetEnabled stitchEnabled shareEnabled   isAd duetDisplay  \
# 0        False       False         False         True  False           0
# 1        False       False         False         True  False           0
# 2        False        True          True         True  False           0
# 3        False       False         False         True  False           0
# 4        False        True          True         True  False           0
# 5        False       False         False         True  False           0
# 6        False       False         False         True  False           0
# 7        False        True          True         True  False           0
# 8        False        True          True         True  False           0
# 9        False        True          True         True  False           0
# 10       False       False         False         True  False           0
# 11       False       False         False         True  False           0
# 12       False        True          True         True  False           0
# 13       False       False         False         True  False           0
# 14       False        True          True         True  False           0
# 15       False        True          True         True  False           0
# 16       False       False         False         True  False           0
# 17       False        True          True         True  False           0
# 18       False        True          True         True  False           0
# 19       False        True          True         True  False           0
# 20       False        True          True         True  False           0
# 21       False        True          True         True  False           0
# 22       False       False         False         True   True           0
# 23       False        True          True         True  False           0
# 24       False       False         False         True  False           0
# 25       False        True          True         True  False           0
# 26       False       False         False         True  False           0
# 27       False       False         False         True   True           0
# 28       False        True          True         True  False           0
# 29       False        True          True         True  False           0
#
#    stitchDisplay                                           warnInfo  \
# 0              0                                                NaN
# 1              0                                                NaN
# 2              0                                                NaN
# 3              0                                                NaN
# 4              0  [{'text': 'Participating in this activity coul...
# 5              0                                                NaN
# 6              0                                                NaN
# 7              0                                                NaN
# 8              0  [{'text': 'Participating in this activity coul...
# 9              0                                                NaN
# 10             0                                                NaN
# 11             0                                                NaN
# 12             0                                                NaN
# 13             0                                                NaN
# 14             0                                                NaN
# 15             0                                                NaN
# 16             0                                                NaN
# 17             0                                                NaN
# 18             0                                                NaN
# 19             0                                                NaN
# 20             0                                                NaN
# 21             0                                                NaN
# 22             0                                                NaN
# 23             0                                                NaN
# 24             0                                                NaN
# 25             0                                                NaN
# 26             0                                                NaN
# 27             0                                                NaN
# 28             0                                                NaN
# 29             0                                                NaN
#
#                                       effectStickers
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20  [{'name': 'Green Screen Video', 'ID': '454774'}]
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
#
# [30 rows x 78 columns]

# %%
df_test.head()
# Out:
#                     id                                               desc  \
# 0  7060891291281853722  Romain Grosjean F1 Accident (Recreate) #f1 #fo...
# 1  7057218917479025925  Michael and Ferrari entering god mode 🐐 cr:@ma...
# 2  7024487957276970245  Now that's impressive #f1 #formula1 #racing #s...
# 3  7076476934401674502  Responder a @alison_ov_30 comenten para última...
# 4  6979913192277298438  One of the scariest things I’ve ever seen.. #f...
#
#            createTime             video_id  video_height  video_width  \
# 0 2022-02-04 16:24:25  7060891291281853722           768          576
# 1 2022-01-25 18:53:44  7057218917479025925           576          720
# 2 2021-10-29 14:00:54  7024487957276970245          1024          576
# 3 2022-03-18 16:24:40  7076476934401674502           960          540
# 4 2021-07-01 11:08:08  6979913192277298438          1024          576
#
#    video_duration video_ratio  \
# 0              68        720p
# 1              44        720p
# 2              19        720p
# 3             124        720p
# 4              55        720p
#
#                                          video_cover  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-usea...
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                    video_originCover  ... authorStats_heart  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-usea...  ...           4000000
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           3200000
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          20000000
# 3  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          10500000
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           2400000
#
#   privateItem duetEnabled stitchEnabled shareEnabled   isAd duetDisplay  \
# 0       False       False         False         True  False           0
# 1       False       False         False         True  False           0
# 2       False        True          True         True  False           0
# 3       False       False         False         True  False           0
# 4       False        True          True         True  False           0
#
#   stitchDisplay                                           warnInfo  \
# 0             0                                                NaN
# 1             0                                                NaN
# 2             0                                                NaN
# 3             0                                                NaN
# 4             0  [{'text': 'Participating in this activity coul...
#
#   effectStickers
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 78 columns]

# %%
df_test.to_csv('TikTokAnalytics.csv')
